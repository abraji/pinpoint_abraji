# %%
# -*- coding: utf-8
# Reinaldo Chaves (@paidatocandeira)
# Exemplo de como baixar PDFs de acórdãos do TCU
#

# %%
import pandas as pd
import wget
import os

# %%
# As planilhas com os dados foram extraídas daqui para cada ano: 
# https://pesquisa.apps.tcu.gov.br/#/resultado/acordao-completo/*/DTRELEVANCIA%253A%255B20100101%2520to%252020211027%255D/%2520
# Trabalhamos com os números de acórdãos que o sistema retornou em cada XLS

# %%
# Exemplo ano 2021

# %%
tcu_2021 = pd.read_excel('tcu/pesquisaExportada_2021.xls',sheet_name='Relatorio')

# %%
tcu_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0    Tipo                                     10000 non-null  object
#  1    Título                                   10000 non-null  object
#  2    Data                                     10000 non-null  object
#  3    Relator                                  9996 non-null   object
#  4    Sumário                                  962 non-null    object
#  5    Processo                                 10000 non-null  object
#  6    Tipo de processo                         9994 non-null   object
#  7    Interessado / Responsável / Recorrente   9840 non-null   object
#  8    Entidade                                 9946 non-null   object
#  9    Representante do Ministério Público      9993 non-null   object
# ...

# %%
tcu_2021.head()
# Out:
#      Tipo                                    Título        Data   \
# 0  ACÓRDÃO  ACÓRDÃO 2608/2021 ATA 42/2021 - PLENÁRIO  27/10/2021
# 1  ACÓRDÃO  ACÓRDÃO 2607/2021 ATA 42/2021 - PLENÁRIO  27/10/2021
# 2  ACÓRDÃO  ACÓRDÃO 2606/2021 ATA 42/2021 - PLENÁRIO  27/10/2021
# 3  ACÓRDÃO  ACÓRDÃO 2605/2021 ATA 42/2021 - PLENÁRIO  27/10/2021
# 4  ACÓRDÃO  ACÓRDÃO 2604/2021 ATA 42/2021 - PLENÁRIO  27/10/2021
#
#            Relator                                            Sumário   \
# 0  MARCOS BEMQUERER  SOLICITAÇÃO DO CONGRESSO NACIONAL. INVESTIGAÇÃ...
# 1  MARCOS BEMQUERER  REPRESENTAÇÃO. ATA DE REGISTRO DE PREÇOS. CONT...
# 2   AUGUSTO SHERMAN  RELATÓRIO DE AUDITORIA DE CONFORMIDADE. OBRAS ...
# 3   AUGUSTO SHERMAN  4º MONITORAMENTO (MDR). FOC GOVERNANÇA E GESTÃ...
# 4   AUGUSTO SHERMAN  AGRAVO. MEDIDA CAUTELAR SUSPENSIVA DE CERTAME....
#
#         Processo                         Tipo de processo   \
# 0  040.853/2021-7  SOLICITAÇÃO DO CONGRESSO NACIONAL (SCN)
# ...

# %%
tcu_2021.columns
# Out:
# Index([' Tipo ', ' Título ', ' Data ', ' Relator ', ' Sumário ', ' Processo ',
#        ' Tipo de processo ', ' Interessado / Responsável / Recorrente ',
#        ' Entidade ', ' Representante do Ministério Público ',
#        ' Unidade Técnica ', ' Representante Legal ', ' Assunto ',
#        ' Endereço do Arquivo '],
#       dtype='object')

# %%
tcu_2021.rename({' Endereço do Arquivo ': 'link'}, axis=1, inplace=True)

# %%
tcu_2021.columns
# Out:
# Index([' Tipo ', ' Título ', ' Data ', ' Relator ', ' Sumário ', ' Processo ',
#        ' Tipo de processo ', ' Interessado / Responsável / Recorrente ',
#        ' Entidade ', ' Representante do Ministério Público ',
#        ' Unidade Técnica ', ' Representante Legal ', ' Assunto ', 'link'],
#       dtype='object')

# %%
# Muda para o diretório que vai receber os arquivos

# %%
os.chdir('D:\\Code\\pinpoint\\repo\\resultados\\tcu')

# %%
# Cria um prefixo do nome que será baixado
# E o contador sequencial do número do arquivo baixado

# %%
nome = 'pesquisaExportada_2021_'
conta = 1

# %%
for num, row in tcu_2022.iterrows():
    vez = row['link']
    print(vez)
    nome_final = nome + str(conta) + '.rtf'
    conta += 1
    
    try:
        wget.download(vez, nome_final)
    except:
        print('Erro')
        pass
# Out:
# https://contas.tcu.gov.br/sagas/SvlVisualizarRelVotoAcRtf?codFiltro=SAGAS-SESSAO-ENCERRADA&seOcultaPagina=S&item0=778865
# 100% [............................................................................] 264779 / 264779https://contas.tcu.gov.br/sagas/SvlVisualizarRelVotoAcRtf?codFiltro=SAGAS-SESSAO-ENCERRADA&seOcultaPagina=S&item0=774662
# 100% [............................................................................] 629384 / 629384https://contas.tcu.gov.br/sagas/SvlVisualizarRelVotoAcRtf?codFiltro=SAGAS-SESSAO-ENCERRADA&seOcultaPagina=S&item0=778694
# 100% [............................................................................] 306526 / 306526https://contas.tcu.gov.br/sagas/SvlVisualizarRelVotoAcRtf?codFiltro=SAGAS-SESSAO-ENCERRADA&seOcultaPagina=S&item0=768063
# ...
